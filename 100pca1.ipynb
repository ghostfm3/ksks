# %% [markdown]
# <a href="https://colab.research.google.com/github/ghostfm3/ksks/blob/master/100pca1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import bz2

# %%
# coding: utf-8
import bz2
fname_input = 'enwiki-20150112-400-r100-10576.txt.bz2'      # 1/100版^^;
fname_output = 'corpus80.txt'

# 1行ずつ処理
with bz2.open(fname_input, 'rt') as data_file, \
        open(fname_output, mode='wt') as out_file:
    for line in data_file:

        # 空白で分解、前後の記号除去
        tokens = []     # 結果のトークン配列
        for chunk in line.split(' '):
            token = chunk.strip().strip('.,!?;:()[]\'"')
            if len(token) > 0:
                tokens.append(token)

        # 出力
        print(*tokens, sep=' ', end='\n', file=out_file)

# %%
# coding: utf-8
fname_input = 'corpus80.txt'
fname_output = 'corpus81.txt'
fname_countries = 'countries.txt'

# 国名一覧を読み込んで集合と辞書作成、ただし1語の国は含めない。
# 辞書には{ 最初の1語, [全体の語数1, 全体の語数2...] }を登録し、
# 全体の語数は降順でソートして格納する。
# たとえば最初の1語が'United'の国は次の6つある。
#   United States of America
#   United Mexican States
#   United Kingdom of Great Britain and Northern Ireland
#   United Arab Emirates
#   United Republic of Tanzania
#   United States
# この場合、全体の語数が4語、3語、8語、2語のものがあるので、
# 辞書には { 'United', [8, 4, 3, 2] } を登録する。
# 全体の個数を降順ソートするのは最長一致でマッチングさせるため。
set_country = set()
dict_country = {}
with open(fname_countries, 'rt') as data_file:
    for line in data_file:
        words = line.split(' ')
        if len(words) > 1:

            # 集合に追加
            set_country.add(line.strip())

            # 辞書に追加
            if words[0] in dict_country:
                lengths = dict_country[words[0]]
                if not len(words) in lengths:
                    lengths.append(len(words))
                    lengths.sort(reverse=True)
            else:
                dict_country[words[0]] = [len(words)]

# 1行ずつ処理
with open(fname_input, 'rt') as data_file, \
        open(fname_output, mode='wt') as out_file:
    for line in data_file:

        # 1語ずつチェック
        tokens = line.strip().split(' ')
        result = []     # 結果のトークン配列
        skip = 0        # >0なら複数語の続き
        for i in range(len(tokens)):

            # 複数語の続きの場合はスキップ
            if skip > 0:
                skip -= 1
                continue

            # 1語目が辞書にある？
            if tokens[i] in dict_country:

                # 後続の語数を切り取って集合にあるかチェック
                hit = False
                for length in dict_country[tokens[i]]:
                    if ' '.join(tokens[i:i + length]) in set_country:

                        # 複数語の国を発見したので'_'で連結して結果に追加
                        result.append('_'.join(tokens[i:i + length]))
                        skip = length - 1       # 残りの語はスキップ
                        hit = True
                        break
                if hit:
                    continue

            # 複数語の国ではないので、そのまま結果に追加
            result.append(tokens[i])

        # 出力
        print(*result, sep=' ', end='\n', file=out_file)

# %%
import random
fname_input = 'corpus81.txt'
fname_output = 'context.txt'

# 1行ずつ処理
with open(fname_input, 'rt') as data_file, \
        open(fname_output, mode='wt') as out_file:
    for i, line in enumerate(data_file):

        # 1語ずつ処理
        tokens = line.strip().split(' ')
        for j in range(len(tokens)):

            t = tokens[j]                   # 単語t
            d = random.randint(1, 5)        # 文脈幅d

            # 前後d語以内の語の列挙
            for k in range(max(j - d, 0), min(j + d + 1, len(tokens))):
                if j != k:
                    print('{}\t{}'.format(t, tokens[k]), file=out_file)

        # 経過表示
        if i % 10000 == 0:
            print('{} done.'.format(i))
# Out:
# 0 done.
# 10000 done.
# 20000 done.
# 30000 done.
# 40000 done.
# 50000 done.
# 60000 done.
# 70000 done.
# 80000 done.
# 90000 done.
# 100000 done.
# 110000 done.
# 120000 done.
# 130000 done.
# 140000 done.
# 150000 done.
# 160000 done.
# 170000 done.
# 180000 done.
# 190000 done.
# 200000 done.
# 210000 done.
# 220000 done.
# 230000 done.
# 240000 done.
# 250000 done.
# 260000 done.
# 270000 done.
# 280000 done.

# %%
# coding: utf-8
from collections import Counter
import pickle

fname_input = 'context.txt'
fname_counter_tc = 'counter_tc'
fname_counter_t = 'counter_t'
fname_counter_c = 'counter_c'


# Counter作成
counter_tc = Counter()
counter_t = Counter()
counter_c = Counter()

# 1行ずつ処理
work_tc = []
work_t = []
work_c = []
with open(fname_input, 'rt') as data_file:
    for i, line in enumerate(data_file, start=1):

        line = line.strip()
        tokens = line.split('\t')

        work_tc.append(line)
        work_t.append(tokens[0])
        work_c.append(tokens[1])

        # 1,000,000行単位でCounterに追加
        if i % 1000000 == 0:
            counter_tc.update(work_tc)
            counter_t.update(work_t)
            counter_c.update(work_c)
            work_tc = []
            work_t = []
            work_c = []
            print('{} done.'.format(i))

# 最後の半端分を追加
counter_tc.update(work_tc)
counter_t.update(work_t)
counter_c.update(work_c)

# Counter書き出し
with open(fname_counter_tc, 'wb') as data_file:
    pickle.dump(counter_tc, data_file)
with open(fname_counter_t, 'wb') as data_file:
    pickle.dump(counter_t, data_file)
with open(fname_counter_c, 'wb') as data_file:
    pickle.dump(counter_c, data_file)

print('N={}'.format(i))
# Out:
# 1000000 done.
# 2000000 done.
# 3000000 done.
# 4000000 done.
# 5000000 done.
# 6000000 done.
# 7000000 done.
# 8000000 done.
# 9000000 done.
# 10000000 done.
# 11000000 done.
# 12000000 done.
# 13000000 done.
# 14000000 done.
# 15000000 done.
# 16000000 done.
# 17000000 done.
# 18000000 done.
# 19000000 done.
# 20000000 done.
# 21000000 done.
# 22000000 done.
# 23000000 done.
# 24000000 done.
# 25000000 done.
# 26000000 done.
# 27000000 done.
# 28000000 done.
# 29000000 done.
# 30000000 done.
# 31000000 done.
# 32000000 done.
# 33000000 done.
# 34000000 done.
# 35000000 done.
# 36000000 done.
# 37000000 done.
# 38000000 done.
# 39000000 done.
# 40000000 done.
# 41000000 done.
# 42000000 done.
# 43000000 done.
# 44000000 done.
# 45000000 done.
# 46000000 done.
# 47000000 done.
# 48000000 done.
# 49000000 done.
# 50000000 done.
# 51000000 done.
# 52000000 done.
# 53000000 done.
# 54000000 done.
# 55000000 done.
# 56000000 done.
# 57000000 done.
# 58000000 done.
# 59000000 done.
# 60000000 done.
# 61000000 done.
# 62000000 done.
# 63000000 done.
# 64000000 done.
# 65000000 done.
# 66000000 done.
# 67000000 done.
# 68000000 done.
# N=68038204

# %%
# coding: utf-8
import math
import pickle
from collections import Counter
from collections import OrderedDict
from scipy import sparse, io

fname_counter_tc = 'counter_tc'
fname_counter_t = 'counter_t'
fname_counter_c = 'counter_c'
fname_matrix_x = 'matrix_x'
fname_dict_index_t = 'dict_index_t'
N = 68031841        # 問題83で求めた定数

# Counter読み込み
with open(fname_counter_tc, 'rb') as data_file:
    counter_tc = pickle.load(data_file)
with open(fname_counter_t, 'rb') as data_file:
    counter_t = pickle.load(data_file)
with open(fname_counter_c, 'rb') as data_file:
    counter_c = pickle.load(data_file)

# {単語, インデックス}の辞書作成
dict_index_t = OrderedDict((key, i) for i, key in enumerate(counter_t.keys()))
dict_index_c = OrderedDict((key, i) for i, key in enumerate(counter_c.keys()))

# 行列作成
size_t = len(dict_index_t)
size_c = len(dict_index_c)
matrix_x = sparse.lil_matrix((size_t, size_c))

# f(t, c)を列挙して処理
for k, f_tc in counter_tc.items():
    if f_tc >= 10:
        tokens = k.split('\t')
        t = tokens[0]
        c = tokens[1]
        ppmi = max(math.log((N * f_tc) / (counter_t[t] * counter_c[c])), 0)
        matrix_x[dict_index_t[t], dict_index_c[c]] = ppmi

# 結果の書き出し
io.savemat(fname_matrix_x, {'matrix_x': matrix_x})
with open(fname_dict_index_t, 'wb') as data_file:
    pickle.dump(dict_index_t, data_file)

# %%
# coding: utf-8
from scipy import sparse, io
import sklearn.decomposition

fname_matrix_x = 'matrix_x'
fname_matrix_x300 = 'matrix_x300'

# 行列読み込み
matrix_x = io.loadmat(fname_matrix_x)['matrix_x']

# 次元圧縮
clf = sklearn.decomposition.TruncatedSVD(300)
matrix_x300 = clf.fit_transform(matrix_x)
io.savemat(fname_matrix_x300, {'matrix_x300': matrix_x300})

# %%
fname_input = 'questions-words.txt'
fname_output = 'family.txt'

with open(fname_input, 'rt') as data_file, \
        open(fname_output, 'wt') as out_file:

    target = False      # 対象のデータ？
    for line in data_file:

        if target is True:

            # 対象データの場合は別のセクションになるまで出力
            if line.startswith(': '):
                break
            print(line.strip(), file=out_file)

        elif line.startswith(': family'):

            # 対象データ発見
            target = True

# %%
# coding: utf-8
import pickle
from collections import OrderedDict
from scipy import io
import numpy as np

fname_dict_index_t = 'dict_index_t'
fname_matrix_x300 = 'matrix_x300'
fname_input = 'family.txt'
fname_output = 'family_out.txt'


def cos_sim(vec_a, vec_b):
    '''コサイン類似度の計算
    ベクトルvec_a、vec_bのコサイン類似度を求める

    戻り値：
    コサイン類似度
    '''
    norm_ab = np.linalg.norm(vec_a) * np.linalg.norm(vec_b)
    if norm_ab != 0:
        return np.dot(vec_a, vec_b) / norm_ab
    else:
        # ベクトルのノルムが0だと似ているかどうかの判断すらできないので最低値
        return -1


# 辞書読み込み
with open(fname_dict_index_t, 'rb') as data_file:
        dict_index_t = pickle.load(data_file)
keys = list(dict_index_t.keys())

# 行列読み込み
matrix_x300 = io.loadmat(fname_matrix_x300)['matrix_x300']

# 評価データ読み込み
with open(fname_input, 'rt') as data_file, \
        open(fname_output, 'wt') as out_file:

    for line in data_file:
        cols = line.split(' ')

        try:

            # ベクトル計算
            vec = matrix_x300[dict_index_t[cols[1]]] \
                    - matrix_x300[dict_index_t[cols[0]]] \
                    + matrix_x300[dict_index_t[cols[2]]]

            # コサイン類似度の一番高い単語を抽出
            dist_max = -1
            index_max = 0
            result = ''
            for i in range(len(dict_index_t)):
                dist = cos_sim(vec, matrix_x300[i])
                if dist > dist_max:
                    index_max = i
                    dist_max = dist

            result = keys[index_max]

        except KeyError:

            # 単語がなければ0文字をコサイン類似度-1で出力
            result = ''
            dist_max = -1

        # 出力
        print('{} {} {}'.format(line.strip(), result, dist_max), file=out_file)
        print('{} {} {}'.format(line.strip(), result, dist_max))
# Out:
# boy girl brother sister brother 0.9643705791376848
# boy girl brothers sisters brothers 0.8793347649553842
# boy girl dad mom mother-in-law 0.840454058302376
# boy girl father mother father 0.9610422367050222
# boy girl grandfather grandmother grandfather 0.8536635994841226
# boy girl grandpa grandma  -1
# boy girl grandson granddaughter grandson 0.7711095511875965
# boy girl groom bride girl 0.6567288124400436
# boy girl he she he 0.9957411857356849
# boy girl his her his 0.9978794363457415
# boy girl husband wife husband 0.9627954858946359
# boy girl king queen king 0.7517835965108276
# boy girl man woman man 0.9221044782275418
# boy girl nephew niece grandmother 0.7795481924100014
# boy girl policeman policewoman girl 0.7091486188170547
# boy girl prince princess girl 0.7790672040657758
# boy girl son daughter son 0.9843363227089166
# boy girl sons daughters sons 0.9480615576387851
# boy girl stepbrother stepsister girl 0.6421450284678032
# boy girl stepfather stepmother mom 0.8483079227932397
# boy girl stepson stepdaughter girl 0.6421450284678032
# boy girl uncle aunt uncle 0.8393727803428086
# brother sister brothers sisters sister 0.5713032900194962
# brother sister dad mom sister 0.40877015326252153
# brother sister father mother mother 0.8498089421875336
# brother sister grandfather grandmother sister 0.5209032074161803
# brother sister grandpa grandma  -1
# brother sister grandson granddaughter sister 0.43828724796308105
# brother sister groom bride Nieces 0.37771288344833664
# brother sister he she he 0.9662578409002723
# brother sister his her his 0.9826615929540592
# brother sister husband wife husband 0.7532063286740049
# brother sister king queen Ann 0.4148889420382799
# brother sister man woman woman 0.5900933059108789
# brother sister nephew niece sister 0.4348145834796571
# brother sister policeman policewoman Nieces 0.37565365790716426
# brother sister prince princess Ann 0.38523736226073013
# brother sister son daughter daughter 0.8611159765722187
# brother sister sons daughters daughters 0.6908553583992327
# brother sister stepbrother stepsister Nieces 0.38195587798127834
# brother sister stepfather stepmother sister 0.4178362852544919
# brother sister stepson stepdaughter Nieces 0.38195587798127834
# brother sister uncle aunt sister 0.4696445381961177
# brother sister boy girl woman 0.4012604516755654
# brothers sisters dad mom mother-in-law 0.7975864340005865
# brothers sisters father mother father 0.9369875652424298
# brothers sisters grandfather grandmother grandmother 0.8183759266289544
# brothers sisters grandpa grandma  -1
# brothers sisters grandson granddaughter grandmother 0.7143487725267459
# brothers sisters groom bride seemingly 0.4751665550933662
# brothers sisters he she he 0.9950260687918769
# brothers sisters his her his 0.9975048870820968
# brothers sisters husband wife husband 0.9455691965245522
# brothers sisters king queen king 0.658550316899332
# brothers sisters man woman man 0.8676298475785152
# brothers sisters nephew niece aunt 0.774425001058835
# brothers sisters policeman policewoman seemingly 0.47427761534746876
# brothers sisters prince princess Maggie 0.48221452624719324
# brothers sisters son daughter son 0.979625193345727
# brothers sisters sons daughters sons 0.9288992339614811
# brothers sisters stepbrother stepsister Maggie 0.43813376612741023
# brothers sisters stepfather stepmother mom 0.8118335452362496
# brothers sisters stepson stepdaughter Maggie 0.43813376612741023
# brothers sisters uncle aunt grandmother 0.7901774780800858
# brothers sisters boy girl boy 0.7012045918963525
# brothers sisters brother sister brother 0.9489537477561383
# dad mom father mother father 0.9740910621578324
# dad mom grandfather grandmother grandfather 0.8855678025861276
# dad mom grandpa grandma  -1
# dad mom grandson granddaughter grandson 0.7660995638646182
# dad mom groom bride quota 0.49445764221864796
# dad mom he she he 0.9979165195396882
# dad mom his her his 0.9989641877649206
# dad mom husband wife husband 0.971493800391582
# dad mom king queen king 0.8237392229956151
# dad mom man woman man 0.9399458756356975
# dad mom nephew niece rescues 0.8568935150472264
# dad mom policeman policewoman surveyor 0.5423752906122651
# dad mom prince princess knight 0.6041175820718473
# dad mom son daughter son 0.9914471962927506
# dad mom sons daughters sons 0.9666248896807552
# dad mom stepbrother stepsister Aunt 0.23678027831227128
# dad mom stepfather stepmother Floss 0.9990616907552454
# dad mom stepson stepdaughter Aunt 0.23678027831227128
# dad mom uncle aunt uncle 0.8697106224429862
# dad mom boy girl boy 0.8429868738405452
# dad mom brother sister brother 0.9790893867766405
# dad mom brothers sisters brothers 0.9195525731190454
# father mother grandfather grandmother mother 0.7248738951359166
# father mother grandpa grandma  -1
# father mother grandson granddaughter mother 0.6526844637381383
# father mother groom bride Blessed 0.5425830957694011
# father mother he she he 0.9873118799567999
# father mother his her his 0.9936621214868913
# father mother husband wife husband 0.8826271909407075
# father mother king queen mother 0.610199711988823
# father mother man woman man 0.7654046859754443
# father mother nephew niece mother 0.6335045112100999
# father mother policeman policewoman Scots 0.5158189674857503
# father mother prince princess Scots 0.5466364577086615
# father mother son daughter son 0.9457333138015913
# father mother sons daughters sons 0.8475674910394557
# father mother stepbrother stepsister Scots 0.530623320257577
# father mother stepfather stepmother grandmother 0.6579646480847176
# father mother stepson stepdaughter Scots 0.530623320257577
# father mother uncle aunt grandmother 0.6669831774169466
# father mother boy girl woman 0.5741514301254387
# father mother brother sister brother 0.8683987121682561
# father mother brothers sisters sisters 0.7379938058159823
# father mother dad mom grandmother 0.631953378258325
# grandfather grandmother grandpa grandma  -1
# grandfather grandmother grandson granddaughter grandmother 0.87254562904912
# grandfather grandmother groom bride lift 0.4898808312226493
# grandfather grandmother he she he 0.9970304222472863
# grandfather grandmother his her his 0.9985149365821422
# grandfather grandmother husband wife husband 0.9614942918442414
# grandfather grandmother king queen king 0.7453532272032327
# grandfather grandmother man woman man 0.9089604812635077
# grandfather grandmother nephew niece aunt 0.871227120291551
# grandfather grandmother policeman policewoman sweet 0.5685142233424876
# grandfather grandmother prince princess Angela 0.5650669152440758
# grandfather grandmother son daughter son 0.9877797307630186
# grandfather grandmother sons daughters sons 0.9525304834163522
# grandfather grandmother stepbrother stepsister Angela 0.48758899565076413
# grandfather grandmother stepfather stepmother aunt 0.8649139522819383
# grandfather grandmother stepson stepdaughter Angela 0.48758899565076413
# grandfather grandmother uncle aunt grandmother 0.910421996235517
# grandfather grandmother boy girl boy 0.7753473431655604
# grandfather grandmother brother sister brother 0.9699173141555792
# grandfather grandmother brothers sisters brothers 0.8893679894424552
# grandfather grandmother dad mom aunt 0.8506925856578772
# grandfather grandmother father mother father 0.9626453020129336
# grandpa grandma grandson granddaughter  -1
# grandpa grandma groom bride  -1
# grandpa grandma he she  -1
# grandpa grandma his her  -1
# grandpa grandma husband wife  -1
# grandpa grandma king queen  -1
# grandpa grandma man woman  -1
# grandpa grandma nephew niece  -1
# grandpa grandma policeman policewoman  -1
# grandpa grandma prince princess  -1
# grandpa grandma son daughter  -1
# grandpa grandma sons daughters  -1
# grandpa grandma stepbrother stepsister  -1
# grandpa grandma stepfather stepmother  -1
# grandpa grandma stepson stepdaughter  -1
# grandpa grandma uncle aunt  -1
# grandpa grandma boy girl  -1
# grandpa grandma brother sister  -1
# grandpa grandma brothers sisters  -1
# grandpa grandma dad mom  -1
# grandpa grandma father mother  -1
# grandpa grandma grandfather grandmother  -1
# grandson granddaughter groom bride maneuver 0.5399363796616405
# grandson granddaughter he she he 0.9973670305102177
# grandson granddaughter his her his 0.9986724144888872
# grandson granddaughter husband wife husband 0.960746856299215
# grandson granddaughter king queen king 0.7690711967668499
# grandson granddaughter man woman man 0.9166725492013749
# grandson granddaughter nephew niece niece 0.8101817823888655
# grandson granddaughter policeman policewoman dwelling 0.6010125100298653
# grandson granddaughter prince princess monarch 0.5737400234857309
# grandson granddaughter son daughter son 0.9892789807661287
# grandson granddaughter sons daughters sons 0.9576445282092032
# grandson granddaughter stepbrother stepsister cab 0.2419418846402024
# grandson granddaughter stepfather stepmother mentor 0.7805401302470252
# grandson granddaughter stepson stepdaughter cab 0.2419418846402024
# grandson granddaughter uncle aunt uncle 0.828866995192032
# grandson granddaughter boy girl boy 0.7936960293928822
# grandson granddaughter brother sister brother 0.9743495743921888
# grandson granddaughter brothers sisters brothers 0.8949047474036315
# grandson granddaughter dad mom beloved 0.7392318605366747
# grandson granddaughter father mother father 0.9711034282943144
# grandson granddaughter grandfather grandmother paternal 0.8708638112313432
# grandson granddaughter grandpa grandma  -1
# groom bride he she he 0.9979608540063376
# groom bride his her his 0.9989755620423248
# groom bride husband wife husband 0.9714418802261422
# groom bride king queen king 0.8860656470136593
# groom bride man woman man 0.9463917895803322
# groom bride nephew niece nephew 0.9402405675128578
# groom bride policeman policewoman bride 0.8800907771696639
# groom bride prince princess bride 0.8621411608896112
# groom bride son daughter son 0.9918907010467131
# groom bride sons daughters sons 0.9724846828062903
# groom bride stepbrother stepsister bride 0.861896655081752
# groom bride stepfather stepmother beloved 0.9400451074001269
# groom bride stepson stepdaughter bride 0.861896655081752
# groom bride uncle aunt uncle 0.9517432635562186
# groom bride boy girl boy 0.8932709370033732
# groom bride brother sister brother 0.9818561640896031
# groom bride brothers sisters brothers 0.946910927620147
# groom bride dad mom father’s 0.9341451588981522
# groom bride father mother father 0.9783751770186734
# groom bride grandfather grandmother grandfather 0.9503253288996711
# groom bride grandpa grandma  -1
# groom bride grandson granddaughter grandson 0.9220054397913602
# he she his her his 0.9135222792121107
# he she husband wife husband 0.5504754343304222
# he she king queen Claire 0.31726720782470297
# he she man woman woman 0.40075185817582104
# he she nephew niece Susan 0.34020678939871035
# he she policeman policewoman Susan 0.2780854200382478
# he she prince princess Claire 0.28379182862380287
# he she son daughter son 0.6635717750470586
# he she sons daughters sons 0.44579187092792116
# he she stepbrother stepsister Susan 0.27859326544023877
# he she stepfather stepmother Ruby 0.38280025805241513
# he she stepson stepdaughter Susan 0.27859326544023877
# he she uncle aunt Susan 0.3560330442743678
# he she boy girl Claire 0.32346000441049566
# he she brother sister brother 0.5124492906336946
# he she brothers sisters sister 0.34427575810180944
# he she dad mom Ruby 0.3639572315903831
# he she father mother mother 0.5436538964558713
# he she grandfather grandmother Susan 0.34962349402973436
# he she grandpa grandma  -1
# he she grandson granddaughter Susan 0.3275383267572879
# he she groom bride Claire 0.2816524297070712
# his her husband wife Carrie 0.4299362423364981
# his her king queen Carrie 0.433818148001156
# his her man woman Carrie 0.42346724504676186
# his her nephew niece Carrie 0.43482992692370553
# his her policeman policewoman Carrie 0.4331460826763741
# his her prince princess Carrie 0.43693792375355045
# his her son daughter her 0.4046776158020964
# his her sons daughters Carrie 0.43375846918879035
# his her stepbrother stepsister Carrie 0.43298446410582486
# his her stepfather stepmother Carrie 0.43820457610536767
# his her stepson stepdaughter Carrie 0.43298446410582486
# his her uncle aunt Carrie 0.4356652476276987
# his her boy girl Carrie 0.43002951499406955
# his her brother sister Carrie 0.43204558642695096
# his her brothers sisters Carrie 0.4472555138387813
# his her dad mom Carrie 0.4296926562139338
# his her father mother Carrie 0.4258677649713753
# his her grandfather grandmother Carrie 0.4354391414027543
# his her grandpa grandma  -1
# his her grandson granddaughter Carrie 0.43094629719411526
# his her groom bride Carrie 0.43275045256983985
# his her he she she 0.7281393864966554
# husband wife king queen wife 0.7349020924267413
# husband wife man woman wife 0.7656091944619556
# husband wife nephew niece née 0.8030472868715973
# husband wife policeman policewoman née 0.7568785372164761
# husband wife prince princess née 0.7521644753310758
# husband wife son daughter son 0.9081648101666564
# husband wife sons daughters sons 0.8071817377164021
# husband wife stepbrother stepsister née 0.7609053030168668
# husband wife stepfather stepmother née 0.7944278389131458
# husband wife stepson stepdaughter née 0.7609053030168668
# husband wife uncle aunt née 0.7977811123058131
# husband wife boy girl wife 0.7503740371461923
# husband wife brother sister daughter 0.8381299334874232
# husband wife brothers sisters daughter 0.7608057866869283
# husband wife dad mom née 0.7907204284090412
# husband wife father mother daughter 0.8971212641018265
# husband wife grandfather grandmother née 0.8126118844560555
# husband wife grandpa grandma  -1
# husband wife grandson granddaughter née 0.7935455001263957
# husband wife groom bride née 0.7560661369802257
# husband wife he she he 0.9606764415724331
# husband wife his her his 0.9803754495693414
# king queen man woman man 0.8741654825403953
# king queen nephew niece nephew 0.7297181574305786
# king queen policeman policewoman balanced 0.45036173555675274
# king queen prince princess queen 0.4130292080131246
# king queen son daughter son 0.9832618710325233
# king queen sons daughters sons 0.9378214874011619
# king queen stepbrother stepsister Goldenfleece 0.20809378772151693
# king queen stepfather stepmother stepfather 0.7699718257324515
# king queen stepson stepdaughter Goldenfleece 0.20809378772151693
# king queen uncle aunt uncle 0.804719471176235
# king queen boy girl boy 0.7226273910966957
# king queen brother sister brother 0.9579880575581123
# king queen brothers sisters brothers 0.8676452053857093
# king queen dad mom dad 0.741588998185797
# king queen father mother father 0.9480646208502943
# king queen grandfather grandmother grandfather 0.816874490735926
# king queen grandpa grandma  -1
# king queen grandson granddaughter grandson 0.712130238770735
# king queen groom bride akin 0.4042434963131756
# king queen he she he 0.9958574735991957
# king queen his her his 0.9979379668983601
# king queen husband wife husband 0.9429625147010263
# man woman nephew niece grandmother 0.716531800328768
# man woman policeman policewoman woman 0.4488972454490196
# man woman prince princess woman 0.5136034669294025
# man woman son daughter son 0.9760079685841854
# man woman sons daughters sons 0.9204794930704578
# man woman stepbrother stepsister Sarah 0.4067426885103844
# man woman stepfather stepmother stepfather 0.7426072997013111
# man woman stepson stepdaughter Sarah 0.4067426885103844
# man woman uncle aunt uncle 0.7585136163451366
# man woman boy girl woman 0.76417725272105
# man woman brother sister brother 0.9439019325328125
# man woman brothers sisters brothers 0.8233434359564459
# man woman dad mom Vivian 0.7214736250724668
# man woman father mother father 0.9359930915720978
# man woman grandfather grandmother grandfather 0.7802421696051243
# man woman grandpa grandma  -1
# man woman grandson granddaughter cousin 0.6639739865372276
# man woman groom bride woman 0.4239650087582271
# man woman he she he 0.9937458949496274
# man woman his her his 0.9968570051036604
# man woman husband wife husband 0.9424558859390604
# man woman king queen king 0.6236596748654177
# nephew niece policeman policewoman tablet 0.5539865742029624
# nephew niece prince princess knight 0.4911040401861427
# nephew niece son daughter son 0.9898478128160219
# nephew niece sons daughters sons 0.9601633475615157
# nephew niece stepbrother stepsister shillings 0.1638985716115405
# nephew niece stepfather stepmother companions 0.8262660449369358
# nephew niece stepson stepdaughter shillings 0.1638985716115405
# nephew niece uncle aunt uncle 0.8651967694401458
# nephew niece boy girl boy 0.8302972305646495
# nephew niece brother sister brother 0.9759872934439513
# nephew niece brothers sisters brothers 0.901170459486964
# nephew niece dad mom beloved 0.7783851941975495
# nephew niece father mother father 0.9733258776461223
# nephew niece grandfather grandmother grandfather 0.8944538548828428
# nephew niece grandpa grandma  -1
# nephew niece grandson granddaughter lord 0.8758724221132583
# nephew niece groom bride transverse 0.49618203429561203
# nephew niece he she he 0.9975036237412984
# nephew niece his her his 0.9987497206444711
# nephew niece husband wife husband 0.9633105336581612
# nephew niece king queen king 0.7991838123269153
# nephew niece man woman man 0.92457383658909
# policeman policewoman prince princess lord 0.7779006935336749
# policeman policewoman son daughter son 0.9970246811770799
# policeman policewoman sons daughters sons 0.9886880782519707
# policeman policewoman stepbrother stepsister Pours 0.030492757784925127
# policeman policewoman stepfather stepmother stepfather 0.9473174651979104
# policeman policewoman stepson stepdaughter Pours 0.030492757784925127
# policeman policewoman uncle aunt uncle 0.9592222348993126
# policeman policewoman boy girl boy 0.9398911117448323
# policeman policewoman brother sister brother 0.9928327394350595
# policeman policewoman brothers sisters brothers 0.9738100147313136
# policeman policewoman dad mom dad 0.9390685251274935
# policeman policewoman father mother father 0.9911097798021113
# policeman policewoman grandfather grandmother grandfather 0.9635923118961006
# policeman policewoman grandpa grandma  -1
# policeman policewoman grandson granddaughter grandson 0.9314626821459991
# policeman policewoman groom bride allotted 0.8242230016423143
# policeman policewoman he she he 0.9992722909048504
# policeman policewoman his her his 0.9996373270489141
# policeman policewoman husband wife husband 0.9895459849473459
# policeman policewoman king queen king 0.9374176552813718
# policeman policewoman man woman man 0.977866817135654
# policeman policewoman nephew niece nephew 0.9370413669682136
# prince princess son daughter son 0.9955313015611823
# prince princess sons daughters sons 0.982600178235065
# prince princess stepbrother stepsister sympathetic 0.4154770361766164
# prince princess stepfather stepmother companions 0.9157657187082283
# prince princess stepson stepdaughter sympathetic 0.4154770361766164
# prince princess uncle aunt uncle 0.9350811770861792
# prince princess boy girl boy 0.9080374741485815
# prince princess brother sister brother 0.9891369855569245
# prince princess brothers sisters brothers 0.9582880755243874
# prince princess dad mom dad 0.8963685766916698
# prince princess father mother father 0.9866154071245883
# prince princess grandfather grandmother grandfather 0.942387710213235
# prince princess grandpa grandma  -1
# prince princess grandson granddaughter grandson 0.8889362618921024
# prince princess groom bride groom 0.7666073620835137
# prince princess he she he 0.9989065781221492
# prince princess his her his 0.9994554033057614
# prince princess husband wife husband 0.9843099445144115
# prince princess king queen king 0.8974159968888975
# prince princess man woman man 0.9666341202108278
# prince princess nephew niece nephew 0.8900039114223053
# prince princess policeman policewoman doll 0.750680394469344
# son daughter sons daughters sons 0.559352283750471
# son daughter stepbrother stepsister Stanhope 0.47635959343668316
# son daughter stepfather stepmother Stanhope 0.44292017158088265
# son daughter stepson stepdaughter Stanhope 0.47635959343668316
# son daughter uncle aunt Stanhope 0.4473263493385812
# son daughter boy girl Stanhope 0.4679686050646405
# son daughter brother sister sister 0.7345509840685928
# son daughter brothers sisters Stanhope 0.47488471334260685
# son daughter dad mom Stanhope 0.4470518483443001
# son daughter father mother mother 0.7228395719888521
# son daughter grandfather grandmother Stanhope 0.4568793828133913
# son daughter grandpa grandma  -1
# son daughter grandson granddaughter Stanhope 0.4671487619155066
# son daughter groom bride Stanhope 0.4724204949515844
# son daughter he she he 0.9432349581344847
# son daughter his her his 0.969947625870554
# son daughter husband wife husband 0.6333385480597472
# son daughter king queen Stanhope 0.4971093317225689
# son daughter man woman woman 0.46068833630193046
# son daughter nephew niece Stanhope 0.46371217532081177
# son daughter policeman policewoman Stanhope 0.471851901776096
# son daughter prince princess Stanhope 0.4708151728034679
# sons daughters stepbrother stepsister Coolidge 0.18656395850159702
# sons daughters stepfather stepmother stepfather 0.712068699486765
# sons daughters stepson stepdaughter Coolidge 0.18656395850159702
# sons daughters uncle aunt uncle 0.7390202486884709
# sons daughters boy girl boy 0.6476323333614913
# sons daughters brother sister brother 0.9445842702324702
# sons daughters brothers sisters brothers 0.7683140457223814
# sons daughters dad mom father’s 0.6777693570639828
# sons daughters father mother father 0.93015316639271
# sons daughters grandfather grandmother grandfather 0.7520654248000276
# sons daughters grandpa grandma  -1
# sons daughters grandson granddaughter grandson 0.5912251060128388
# sons daughters groom bride groom 0.31043280475694246
# sons daughters he she he 0.9943899159355081
# sons daughters his her his 0.9971989121723879
# sons daughters husband wife husband 0.921041409953339
# sons daughters king queen king 0.6260792136042581
# sons daughters man woman man 0.8329088537010517
# sons daughters nephew niece nephew 0.651894661614173
# sons daughters policeman policewoman capsule 0.3522409221316519
# sons daughters prince princess patron 0.29066794566664733
# sons daughters son daughter son 0.9789023461802866
# stepbrother stepsister stepfather stepmother stepfather 0.9999999999999998
# stepbrother stepsister stepson stepdaughter Anarchism -1
# stepbrother stepsister uncle aunt uncle 1.0000000000000002
# stepbrother stepsister boy girl boy 1.0
# stepbrother stepsister brother sister brother 1.0000000000000004
# stepbrother stepsister brothers sisters brothers 1.0000000000000002
# stepbrother stepsister dad mom dad 1.0
# stepbrother stepsister father mother father 0.9999999999999999
# stepbrother stepsister grandfather grandmother grandfather 0.9999999999999998
# stepbrother stepsister grandpa grandma  -1
# stepbrother stepsister grandson granddaughter grandson 0.9999999999999997
# stepbrother stepsister groom bride groom 1.0
# stepbrother stepsister he she he 0.9999999999999999
# stepbrother stepsister his her his 0.9999999999999997
# stepbrother stepsister husband wife husband 1.0000000000000002
# stepbrother stepsister king queen king 1.0
# stepbrother stepsister man woman man 1.0
# stepbrother stepsister nephew niece nephew 0.9999999999999999
# stepbrother stepsister policeman policewoman policeman 1.0
# stepbrother stepsister prince princess prince 0.9999999999999997
# stepbrother stepsister son daughter son 1.0000000000000002
# stepbrother stepsister sons daughters sons 1.0
# stepfather stepmother stepson stepdaughter anti-statism 0.09451950123620967
# stepfather stepmother uncle aunt nuns 0.5788292788074707
# stepfather stepmother boy girl boy 0.6359343262305679
# stepfather stepmother brother sister brother 0.9343666801604431
# stepfather stepmother brothers sisters brothers 0.7522761094656956
# stepfather stepmother dad mom self-governed 0.05187316560399191
# stepfather stepmother father mother father 0.918296520151226
# stepfather stepmother grandfather grandmother grandfather 0.5751861395565872
# stepfather stepmother grandpa grandma  -1
# stepfather stepmother grandson granddaughter ruler 0.6041390541493316
# stepfather stepmother groom bride groom 0.3000818672130934
# stepfather stepmother he she he 0.9936532754331098
# stepfather stepmother his her his 0.9968389254164226
# stepfather stepmother husband wife husband 0.9039082738893934
# stepfather stepmother king queen king 0.6117001861042469
# stepfather stepmother man woman man 0.8299038965420666
# stepfather stepmother nephew niece great-grandfather 0.46925498094050916
# stepfather stepmother policeman policewoman conscientious 0.32086648171898824
# stepfather stepmother prince princess knight 0.3648921878508843
# stepfather stepmother son daughter son 0.9736184659530176
# stepfather stepmother sons daughters sons 0.8944278341881351
# stepfather stepmother stepbrother stepsister anti-statism 0.09451950123620967
# stepson stepdaughter uncle aunt uncle 1.0000000000000002
# stepson stepdaughter boy girl boy 1.0
# stepson stepdaughter brother sister brother 1.0000000000000004
# stepson stepdaughter brothers sisters brothers 1.0000000000000002
# stepson stepdaughter dad mom dad 1.0
# stepson stepdaughter father mother father 0.9999999999999999
# stepson stepdaughter grandfather grandmother grandfather 0.9999999999999998
# stepson stepdaughter grandpa grandma  -1
# stepson stepdaughter grandson granddaughter grandson 0.9999999999999997
# stepson stepdaughter groom bride groom 1.0
# stepson stepdaughter he she he 0.9999999999999999
# stepson stepdaughter his her his 0.9999999999999997
# stepson stepdaughter husband wife husband 1.0000000000000002
# stepson stepdaughter king queen king 1.0
# stepson stepdaughter man woman man 1.0
# stepson stepdaughter nephew niece nephew 0.9999999999999999
# stepson stepdaughter policeman policewoman policeman 1.0
# stepson stepdaughter prince princess prince 0.9999999999999997
# stepson stepdaughter son daughter son 1.0000000000000002
# stepson stepdaughter sons daughters sons 1.0
# stepson stepdaughter stepbrother stepsister Anarchism -1
# stepson stepdaughter stepfather stepmother stepfather 0.9999999999999998
# uncle aunt boy girl boy 0.7697418410744724
# uncle aunt brother sister brother 0.9708447462012244
# uncle aunt brothers sisters brothers 0.8869822535901388
# uncle aunt dad mom aunt 0.8087800976689529
# uncle aunt father mother father 0.9643933083560391
# uncle aunt grandfather grandmother grandmother 0.882399076440851
# uncle aunt grandpa grandma  -1
# uncle aunt grandson granddaughter aunt 0.7844765216734988
# uncle aunt groom bride quota 0.4540362743058662
# uncle aunt he she he 0.9971177929543138
# uncle aunt his her his 0.998564533213523
# uncle aunt husband wife husband 0.9606771989413456
# uncle aunt king queen king 0.7508711722997009
# uncle aunt man woman man 0.9105619939362469
# uncle aunt nephew niece aunt 0.8475878520626294
# uncle aunt policeman policewoman cooperative 0.48821315272128274
# uncle aunt prince princess skull 0.4719258918667293
# uncle aunt son daughter son 0.9882004419392391
# uncle aunt sons daughters sons 0.9532608717090643
# uncle aunt stepbrother stepsister Jacqui 0.28744439766289265
# uncle aunt stepfather stepmother aunt 0.8321699516160662
# uncle aunt stepson stepdaughter Jacqui 0.28744439766289265

# %%
fname_input = 'family_out.txt'

with open(fname_input, 'rt') as data_file:

    # 1行ずつチェック
    correct = 0
    total = 0

    for line in data_file:
        cols = line.split(' ')
        total += 1
        if cols[3] == cols[4]:
            correct += 1

# 正解率表示
print('{} ({}/{})'.format(correct / total, correct, total))
# Out:
# 0.02766798418972332 (14/506)
